# %%
import requests #用於API HTTP requests
import pandas as pd


def amap_api_search_by_keyword_city_code(qw, er, e07cfb499b1e012bafee0d4aedcb4d90):

    parameters = {'key': e07cfb499b1e012bafee0d4aedcb4d90}  # 高德地图API 获取Key
    parameters.update( {'keywords': qw,
                        'city':     er,
                        'citylimit': True
                       } )

    pois = []   # 建构最终结果列表pois
    pg_no = 1   # 建构pg_no，每次给不一样的可选参数page值

    while True: # 不断迭代，直到 break跳出
        parameters.update({'page':pg_no})  #建构可选参数page值 为 pg_no

        r = requests.get ("http://restapi.amap.com/v3/place/text", params=parameters)
        data = r.json()

        pois.extend(data['pois'])         # 使用Python列表之extend方法，把返回数据中的结果data['pois']存入pois


        no_pois_this_search = len(pois)   # 计算 累积实质结果数
        no_pois = int(data['count'])      # 计算 应有的实质数量


        if (no_pois_this_search >= no_pois):  # 若 累积实质结果数 >= 应有的实质数量
            break                                   # 则结束迭代跳出
        else:
            pg_no +=1                               # 否则找下一页数据，把 pg_no增1


    # 使用pandas 模块处理数据
    df_input = pd.DataFrame(pois)

    # 选择部份栏位准备输出
    select_fields = "location	address	adname	cityname	id	importance	name	pname	tel	type	typecode".split("\t")
    df = df_input[select_fields]

    # 经纬度 增加新栏位字段
    df = df.assign( 经 = [x.split(',')[0] for x in df['location']])
    df = df.assign( 纬 = [x.split(',')[1] for x in df['location']])
    df = df.assign(keywords = [qw]*len(df['location']))

    
    # 使用 return返回
    return(df)

# %%
 keywords_fields = "华硕	联想	戴尔	星巴克".split("\t")

# %%
g_list=[]

for y in  keywords_fields:
    z=amap_api_search_by_keyword_city_code(y, '中国', 'ee83ffb0500bcbbe5929a0d58d012e0e')
   
    g_list.append(z)

# %%
df=pd.concat(g_list)

# %%
df
# Out:
#                  location                                address adname  \
# 0    120.145569,33.400047                     开放大道103号新纪元商业广场B1层    亭湖区
# 1    109.503753,18.257408                        解放路668号三亚明珠广场1层    天涯区
# 2    118.343460,35.051445                     金雀山路沂蒙大楼1层(临商银行东边)    兰山区
# 3    109.603775,23.095020                            江北大道丰宝商业城1层    港北区
# 4    120.160933,30.263085                              凤起路519号3幢    下城区
# 5    103.766213,29.555172                        中土桥街61号金杯银座1-2层    市中区
# 6    120.164376,30.241119                           延安路1号吴山名楼1号楼    上城区
# 7    102.730680,25.013201                       春城路289号沃尔玛购物广场1层    官渡区
# 8    120.170299,30.250427                         解放路199号(中山中路口)    上城区
# 9    110.288831,25.269709                          中山中路3号维也纳酒店2层    象山区
# 10   119.178590,34.604254                                解放中路37号    海州区
# 11   114.458985,38.010887                           红旗大街666号一、二层    桥西区
# 12   100.216617,25.585008                             建设路(人民公园旁)    大理市
# 13   120.125656,30.276765                      文三路478号华星时代广场C座1层    西湖区
# 14   110.280178,25.254240                 环城西一路117号联达商业广场1号楼1-2层    象山区
# 15   113.323196,23.115488                           珠江路1号广州大剧院1层    天河区
# 16   106.708039,26.577092                         中山西路78号国晨百货b1层    南明区
# 17   120.342811,36.057945                  文登路中段汇泉广场B1层C区(影城斜对面)    市南区
# 857  121.421660,31.186857                 中山西路1602号宏汇国际广场B座1层02室    徐汇区
# 858  120.626389,31.292549                              竹辉路赛格广场一楼    姑苏区
# 859  120.177255,30.278792                        朝晖路108号102室和平饭店    下城区
# 860  121.558158,31.226326                          芳甸路300号联洋广场1层   浦东新区
#
#     cityname          id importance              name    pname  \
# 0        盐城市  B0FFHPAO7T         []               肯德基      江苏省
# 1        三亚市  B0383010UW         []          肯德基(解放店)      海南省
# 2        临沂市  B021B0BVN0         []        肯德基(金雀山路店)      山东省
# 3        贵港市  B06DB005NB         []          肯德基(贵港店)  广西壮族自治区
# 4        杭州市  B023B09LTL         []       肯德基(武林服饰城店)      浙江省
# 5        乐山市  B0341018W1         []        肯德基(金杯银座店)      四川省
# 6        杭州市  B023B08SI2         []        肯德基(杭州吴山店)      浙江省
# 7        昆明市  B036705OGR         []          肯德基(山姆店)      云南省
# 8        杭州市  B023B09GEO         []        肯德基(杭州永安店)      浙江省
# 9        桂林市  B0305096QN         []          肯德基(西城店)  广西壮族自治区
# 10      连云港市  B020600B8M         []        肯德基(解放中路店)      江苏省
# 11      石家庄市  B013704TVA         []        肯德基(红旗大街店)      河北省
# 12   大理白族自治州  B0368009YJ         []      肯德基(大理人民公园店)      云南省
# 13       杭州市  B023B08W26         []        肯德基(杭州文三店)      浙江省
# 14       桂林市  B030509B3S         []          肯德基(联达店)  广西壮族自治区
# 15       广州市  B00141JN52         []         肯德基(大剧院店)      广东省
# 16       贵阳市  B035301OXW         []          肯德基(腾达店)      贵州省
# 17       青岛市  B021407P5S         []        肯德基(汇泉广场店)      山东省
# 18       淄博市  B021503ZY0         []          肯德基(中心店)      山东省
# 19       北京市  B000A84ZD1         []          肯德基(来福士)      北京市
# 20       南京市  B001905OYQ         []         肯德基(狮子桥店)      江苏省
# 21       广州市  B00140UI3A         []        肯德基(东峻广场店)      广东省
# 22       郑州市  B017315XPG         []         肯德基(商都路店)      河南省
# 23       绍兴市  B023F0P2TQ         []          肯德基(中兴店)      浙江省
# 24       南宁市  B03030702X         []       肯德基(城市碧园C座)  广西壮族自治区
# 25       潍坊市  B021815O4F         []        肯德基(人民公园店)      山东省
# 26       苏州市  B020016CIN         []        肯德基(园区华池店)      江苏省
# 27       长沙市  B02DB02EXX         []        肯德基(中央广场店)      湖南省
# 28       杭州市  B023B02N8Q         []          肯德基(上乘店)      浙江省
# 29       成都市  B001C7Y80U         []          肯德基(文武店)      四川省
# ..       ...         ...        ...               ...      ...
# 831      东莞市  B0FFG4RMXZ         []     星巴克咖啡(益田假日天地)      广东省
# 832      苏州市  B0FFHM8BTJ         []   星巴克咖啡(苏州茉莉花假日店)      江苏省
# 833      南京市  B0FFGF91P2         []     星巴克咖啡(南京张府园店)      江苏省
# 834      上海市  B0FFHEFH4K         []       星巴克咖啡(嘉亭荟店)      上海市
# 835      广州市  B00140TCRJ         []    星巴克咖啡(中石化大厦分店)      广东省
# 836      上海市  B0FFFAF1DD         []       星巴克咖啡(正大广场)      上海市
# 13                 0571-86689651;4008823823      餐饮服务;快餐厅;肯德基   050301
# 14                0773-3851655;0773-3851622      餐饮服务;快餐厅;肯德基   050301
# 15                             020-37021971      餐饮服务;快餐厅;肯德基   050301
# 16   0851-85821770;0851-85830861;4008823823      餐饮服务;快餐厅;肯德基   050301
# 17   0532-82871598;0532-82871568;4008823823      餐饮服务;快餐厅;肯德基   050301
# 18                             0533-2152158      餐饮服务;快餐厅;肯德基   050301
# 19     010-84094503;010-84094508;4008823823      餐饮服务;快餐厅;肯德基   050301
# 20      025-83243744;4008823823;18951765519      餐饮服务;快餐厅;肯德基   050301
# 21                020-87675519;020-87670632      餐饮服务;快餐厅;肯德基   050301
# 22                 0371-53386311;4008823823      餐饮服务;快餐厅;肯德基   050301
# 23                            0575-85121601      餐饮服务;快餐厅;肯德基   050301
# 24     0771-3833909;0771-3829599;4008823823      餐饮服务;快餐厅;肯德基   050301
# 25                             0536-8560550      餐饮服务;快餐厅;肯德基   050301
# 26                            0512-62856784      餐饮服务;快餐厅;肯德基   050301
# 27   0731-82237310;0731-84422175;4008823823      餐饮服务;快餐厅;肯德基   050301
# 28                            0571-86512865      餐饮服务;快餐厅;肯德基   050301
# 29                               4008823823      餐饮服务;快餐厅;肯德基   050301
# ..                                      ...               ...      ...
# 831                0769-82850175;4008206998    餐饮服务;咖啡厅;星巴克咖啡   050501
# 832                           0512-68755624    餐饮服务;咖啡厅;星巴克咖啡   050501
# 833                 025-58750533;4008206998    餐饮服务;咖啡厅;星巴克咖啡   050501
# 834                            021-39127310    餐饮服务;咖啡厅;星巴克咖啡   050501
# 835                            020-38922050    餐饮服务;咖啡厅;星巴克咖啡   050501
# 836               021-50471106;021-56712970    餐饮服务;咖啡厅;星巴克咖啡   050501
# 837                           0510-82307387    餐饮服务;咖啡厅;星巴克咖啡   050501
# 838                            021-62360782    餐饮服务;咖啡厅;星巴克咖啡   050501
# 839                           0571-86870180    餐饮服务;咖啡厅;星巴克咖啡   050501
# 840                           0571-87399615    餐饮服务;咖啡厅;星巴克咖啡   050501
# 841                            023-67077706    餐饮服务;咖啡厅;星巴克咖啡   050501
# 842                            021-56528235    餐饮服务;咖啡厅;星巴克咖啡   050501
# 843                           0571-87798162    餐饮服务;咖啡厅;星巴克咖啡   050501
# 844                028-68277875;18048561037    餐饮服务;咖啡厅;星巴克咖啡   050501
# 845                            021-62363070    餐饮服务;咖啡厅;星巴克咖啡   050501
# 846                            021-62590868    餐饮服务;咖啡厅;星巴克咖啡   050501
# 847                            021-64480045    餐饮服务;咖啡厅;星巴克咖啡   050501
# 848                           0512-67913298  餐饮服务;餐饮相关场所;餐饮相关   050000
# 849                           0755-33356661    餐饮服务;咖啡厅;星巴克咖啡   050501
# 850               010-85187361;010-85186363    餐饮服务;咖啡厅;星巴克咖啡   050501
# 851                              4008206998    餐饮服务;咖啡厅;星巴克咖啡   050501
# 852                            028-82363627    餐饮服务;咖啡厅;星巴克咖啡   050501
