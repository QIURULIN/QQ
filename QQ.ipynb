# %%
import requests #用於API HTTP requests
import pandas as pd


def amap_api_search_by_keyword_city_code(qw, er, e07cfb499b1e012bafee0d4aedcb4d90):

    parameters = {'key': e07cfb499b1e012bafee0d4aedcb4d90}  # 高德地图API 获取Key
    parameters.update( {'keywords': qw,
                        'city':     er,
                        'citylimit': True
                       } )

    pois = []   # 建构最终结果列表pois
    pg_no = 1   # 建构pg_no，每次给不一样的可选参数page值

    while True: # 不断迭代，直到 break跳出
        parameters.update({'page':pg_no})  #建构可选参数page值 为 pg_no

        r = requests.get ("http://restapi.amap.com/v3/place/text", params=parameters)
        data = r.json()

        pois.extend(data['pois'])         # 使用Python列表之extend方法，把返回数据中的结果data['pois']存入pois


        no_pois_this_search = len(pois)   # 计算 累积实质结果数
        no_pois = int(data['count'])      # 计算 应有的实质数量


        if (no_pois_this_search >= no_pois):  # 若 累积实质结果数 >= 应有的实质数量
            break                                   # 则结束迭代跳出
        else:
            pg_no +=1                               # 否则找下一页数据，把 pg_no增1


    # 使用pandas 模块处理数据
    df_input = pd.DataFrame(pois)

    # 选择部份栏位准备输出
    select_fields = "location	address	adname	cityname	id	importance	name	pname	tel	type	typecode".split("\t")
    df = df_input[select_fields]

    # 经纬度 增加新栏位字段
    df = df.assign( 经 = [x.split(',')[0] for x in df['location']])
    df = df.assign( 纬 = [x.split(',')[1] for x in df['location']])
    df = df.assign(keywords = [qw]*len(df['location']))

    
    # 使用 return返回
    return(df)

# %%
 keywords_fields = "华硕	联想	戴尔	惠普".split("\t")

# %%
g_list=[]

for y in  keywords_fields:
    z=amap_api_search_by_keyword_city_code(y, '中国', 'e07cfb499b1e012bafee0d4aedcb4d90')
   
    g_list.append(z)

# %%
df=pd.concat(g_list)

# %%
df
# Out:
#                  location                      address   adname cityname  \
# 0    114.396373,23.082732                鹅岭北路16号1号楼49铺      惠城区      惠州市
# 1    118.089773,24.468780            湖滨南路69号厦门电子城1层107      思明区      厦门市
# 2    115.821181,32.899103                      太平巷194号      颍泉区      阜阳市
# 3    116.263554,28.370345             岚湖路与贤湖路交叉口西南100米      进贤县      南昌市
# 4    117.117259,40.142486                       新开街27号      平谷区      北京市
# 5    119.198052,36.413602       兴安街办一马路南首步步高家园沿街印台食府对面      安丘市      潍坊市
# 6    106.249233,30.000971             义乌大道16-2-2-57号附近      合川区      重庆市
# 7    119.357777,34.089268           新东南路12-5号(圆通快递斜对面)      灌南县     连云港市
# 8    121.497065,31.162001                上南路3030号127A铺     浦东新区      上海市
# 9    106.844623,32.356642              南江镇光雾山大道红星段335号      南江县      巴中市
# 10   120.822386,31.618096           古里镇东南开发区小康村金华路118号      常熟市      苏州市
# 11   108.039804,30.294044                       果园路14号       忠县      重庆市
# 12   122.733403,41.513386                       北一路69号      辽中区      沈阳市
# 13   120.027240,32.160713                    永丰路59-13号      泰兴市      泰州市
# 14   104.424755,29.454629                      桂林街128号       荣县      自贡市
# 15   119.450504,32.201482                   健康路42-108号      京口区      镇江市
# 16   115.394499,37.363478           大庆路蓝天东方乐购超市西行70米路北      南宫市      邢台市
# 17   105.814237,28.038746                       滨河路10号      古蔺县      泸州市
# 18   116.102408,25.095192              政府路中国建设银行西北侧70米      武平县      龙岩市
# 680               购物服务;购物相关场所;购物相关场所         060000  113.308559  23.095795
# 681               购物服务;购物相关场所;购物相关场所         060000  106.605443  29.684145
# 682               购物服务;购物相关场所;购物相关场所         060000  117.183589  34.263825
# 683               购物服务;购物相关场所;购物相关场所         060000  104.066313  30.601481
# 684               购物服务;购物相关场所;购物相关场所         060000  111.601360  26.448214
# 685               购物服务;购物相关场所;购物相关场所         060000  120.666510  27.781566
# 686                 购物服务;家电电子卖场;数码电子         060306  129.429863  47.412863
# 687                     医疗保健服务;诊所;诊所         090300  117.085483  36.148181
# 688               购物服务;购物相关场所;购物相关场所         060000  113.365691  22.940413
# 689               购物服务;购物相关场所;购物相关场所         060000  113.371113  22.938084
# 690               购物服务;购物相关场所;购物相关场所         060000  114.068825  35.414852
# 691               购物服务;家电电子卖场;家电电子卖场         060300  113.770506  34.227588
# 692               购物服务;购物相关场所;购物相关场所         060000  121.111966  31.149188
# 693               购物服务;购物相关场所;购物相关场所         060000  105.813085  28.039016
# 694               购物服务;购物相关场所;购物相关场所         060000  113.447189  23.103627
# 695               购物服务;家电电子卖场;家电电子卖场         060300  113.255981  22.953331
# 696                     购物服务;专卖店;专营店         061200  117.967253  36.651344
# 697               购物服务;购物相关场所;购物相关场所         060000  121.226809  31.013944
# 698               购物服务;购物相关场所;购物相关场所         060000  111.544150  29.041481
# 699               购物服务;购物相关场所;购物相关场所         060000  114.278070  22.728246
# 700               购物服务;购物相关场所;购物相关场所         060000  104.749147  31.769853
# 701               购物服务;购物相关场所;购物相关场所         060000  115.661416  33.632649
# 702            医疗保健服务;医药保健销售店;医疗保健用品         090602  126.548561  43.841874
# 703           金融保险服务;金融保险服务机构;金融保险机构         160000  120.210428  29.281870
# 704               购物服务;家电电子卖场;家电电子卖场         060300  119.996174  31.433021
# 705                 购物服务;家电电子卖场;数码电子         060306  116.294785  38.489080
# 706                 购物服务;家电电子卖场;数码电子         060306  117.129931  36.191034
# 707               生活服务;生活服务场所;生活服务场所         070000  111.584722  25.187089
# 708                 购物服务;家电电子卖场;数码电子         060306  101.780590  36.621010
#
#     keywords
# 0         华硕
# 1         华硕
# 2         华硕
# 3         华硕
# 4         华硕
# 5         华硕
# 6         华硕
# 7         华硕
# 8         华硕
# 9         华硕
# 10        华硕
# 11        华硕
# 12        华硕
# 13        华硕
# 14        华硕
# 15        华硕
# 16        华硕
# 17        华硕
# 18        华硕
# 19        华硕
# 20        华硕
# 21        华硕
# 22        华硕
# 23        华硕
# 24        华硕
# 25        华硕
# 26        华硕
# 27        华硕
# 28        华硕
# 29        华硕
# ..       ...
# 679       惠普
# 680       惠普
# 681       惠普
# 682       惠普
# 683       惠普
# 684       惠普
# 685       惠普
# 686       惠普
# 687       惠普
# 688       惠普
# 689       惠普
# 690       惠普
# 691       惠普
# 692       惠普
# 693       惠普
# 694       惠普
# 695       惠普
# 696       惠普
# 697       惠普
# 698       惠普
# 699       惠普
# 700       惠普
# 701       惠普
# 702       惠普
# 703       惠普
# 704       惠普
# 705       惠普
# 706       惠普
# 707       惠普
# 708       惠普
#
# [2985 rows x 14 columns]

# %%
df.to_csv('QQ.tsv',encoding='utf8',sep='\t')
